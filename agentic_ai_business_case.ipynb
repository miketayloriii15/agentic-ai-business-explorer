# %%
"""
This script demonstrates a multi-step conversation with the OpenAI API.

Workflow:
- Step 1: Ask the model (acting as a Fortune 500 business leader) to select a business area
  that could benefit from Agentic AI adoption.
- Step 2: Append the model’s response to the conversation history.
- Step 3: Ask the model to identify a critical pain point in that same industry
  that could be addressed by Agentic AI.

The script prints both:
- The initial business idea
- The identified pain point

Notes:
- Requires an environment variable named OPENAI_API_KEY to be set.
- Intended as a practice/demo for working with multi-turn prompts.
"""

# Load the OpenAI API key from environment variables and confirm it exists.
# This prevents accidental errors if the key is missing.
# Then initialize the OpenAI client, which will be used to make chat completion calls.
import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
    

from openai import OpenAI
openai = OpenAI()


# 1. Start conversation
messages = [
    {"role": "system", "content": "You are a Fortune 500 business leader evaluating strategic opportunities."},
    {"role": "user", "content": "Select one business area that could significantly benefit from Agentic AI adoption. Clearly explain why this area is worth exploring, the potential value it could create, and the challenges that might arise in implementing such a solution."}
]

# First call
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)
business_idea = response.choices[0].message.content
print("=== Business Idea ===")
print(business_idea)

# Save assistant response into history
messages.append({"role": "assistant", "content": business_idea})

# 2. Ask for a pain point in that industry
messages.append({
    "role": "user",
    "content": "Identify one critical pain point in this industry—something costly, inefficient, or difficult to scale—that could be ripe for an Agentic AI solution. Explain why this challenge exists, its impact on the business, and why Agentic AI is well-suited to address it."
})

# Second call
response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)
pain_point = response.choices[0].message.content
print("\n=== Pain Point ===")
print(pain_point)
# Out:
# OpenAI API Key exists and begins sk-proj-
# === Business Idea ===
# One business area that could significantly benefit from Agentic AI adoption is **Supply Chain Management (SCM).**
#
# ### Why this area is worth exploring:
# Supply Chain Management is a complex, dynamic system involving multiple interconnected processes—procurement, production, logistics, inventory management, demand forecasting, and distribution. Traditional SCM relies heavily on human decision-making and rule-based automation, which often struggle to respond swiftly and holistically to disruptions, changing market demands, and evolving regulations.
#
# Agentic AI, with its autonomous decision-making capabilities and ability to interact proactively with multiple agents and systems, can fundamentally transform SCM. It can manage uncertainty, optimize across multiple conflicting objectives (cost, speed, sustainability), and adapt in real-time to disruptions or shifts in demand.
#
# ### Potential value creation:
# 1. **Enhanced operational efficiency**: Agentic AI can autonomously monitor supply and demand patterns, reorder inventory dynamically, optimize transportation routes, and schedule production, significantly reducing lead times and operational costs.
# 2. **Improved resilience and risk management**: By proactively identifying risks (supplier delays, geopolitical risks, natural disasters), agentic systems can propose contingency plans or switch suppliers automatically, minimizing downtime and losses.
# 3. **Increased agility and customer satisfaction**: Faster, smarter adjustments to supply chain flows lead to better product availability, fewer stockouts, and quicker response to customer preferences, improving service levels.
# 4. **Sustainability and compliance**: AI can optimize for carbon footprints and regulatory adherence by choosing environmentally friendly transportation modes and suppliers that meet sustainability standards.
# 5. **Data-driven strategic insights**: Continuous autonomous analysis generates insights for long-term strategic decisions and investments.
#
# ### Challenges in implementation:
# 1. **Data integration and quality**: Effective agentic AI requires comprehensive, real-time data across all elements of the supply chain, which may be scattered across disparate legacy systems or partners with varying data standards.
# 2. **Complex stakeholder coordination**: Supply chains involve multiple parties (suppliers, logistics providers, distributors), requiring alignment on technology adoption, trust, and data sharing, which is often difficult to achieve.
# 3. **Trust and control**: Organizations might resist ceding decision rights to autonomous agents, fearing loss of human oversight or unintended consequences from AI actions.
# 4. **Scalability and robustness**: Ensuring that agentic AI systems operate reliably at scale, managing millions of transactions and exceptions without failures, is challenging.
# 5. **Cybersecurity risks**: Increased automation and connectivity can raise exposure to cyber threats, requiring robust security frameworks.
#
# ---
#
# **Summary:**
# Investing in Agentic AI for Supply Chain Management offers a compelling opportunity to radically improve efficiency, resilience, and customer responsiveness while aligning with sustainability goals. Addressing data challenges, stakeholder collaboration, and trust will be critical to successful adoption. This strategic initiative can position the company as an innovation leader in operational excellence.
#
# === Pain Point ===
# ### Critical Pain Point: **Demand Forecasting and Inventory Optimization**
#
# #### Why this challenge exists:
# Demand forecasting and inventory optimization in Supply Chain Management are notoriously complex due to the high variability and uncertainty in consumer behavior, market trends, seasonality, and external disruptions (e.g., supplier delays, geopolitical events, pandemics). Traditional forecasting methods often rely on historical data and statistical models that cannot fully capture real-time shifts or interdependencies within the supply network. Inventory optimization requires balancing conflicting goals—minimizing stockouts without overstocking, reducing holding costs while meeting service levels—which becomes exponentially harder as product lines, suppliers, and distribution channels grow.
#
# #### Impact on the business:
# - **High costs**: Poor demand forecasts lead to excess inventory, resulting in storage costs and obsolescence, or stockouts, leading to lost sales and customer dissatisfaction.
# - **Reduced agility**: Slow or inaccurate responses to demand fluctuations hurt the ability to capitalize on market opportunities or respond to competitive pressures.
# - **Inefficient capital allocation**: Inventory tied up in slow-moving products reduces cash flow and limits investment in growth areas.
# - **Operational disruptions**: Misaligned inventory levels cascade into production delays, expedited shipping costs, and rushed supplier orders.
#
# #### Why Agentic AI is well-suited to address it:
# - **Autonomous, real-time data integration**: Agentic AI can continuously gather and integrate data from diverse sources including sales, market signals, social media trends, weather patterns, and supplier performance to create a dynamic, up-to-the-minute view.
# - **Adaptive learning and decision-making**: Instead of static models, agentic systems learn from continually changing data and outcomes, refining demand forecasts and inventory recommendations autonomously.
# - **Multi-agent collaboration**: Different AI agents can represent suppliers, warehouses, and distribution centers, negotiating and coordinating to optimize stock levels and reorder points across the entire network.
# - **Scenario simulation and proactive planning**: Agentic AI can simulate various demand and supply scenarios, identifying risks and recommending contingency plans before issues arise.
# - **Scalability**: As product assortments and partner networks expand, agentic AI can scale decision-making without proportional increases in human oversight or manual processes.
#
# ---
#
# **In summary**, the recurring challenge of inaccurate demand forecasting combined with inventory inefficiencies severely impacts supply chain costs and responsiveness. Agentic AI’s autonomous, adaptive, and collaborative capabilities uniquely position it to transform this pain point into a competitive advantage by continuously optimizing inventory aligned with real-time, complex market dynamics.
